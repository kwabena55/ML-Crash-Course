# %% [markdown]
# # Seaborn

# %%
#import libraries
import seaborn as sns

# %%
sns.get_dataset_names()  # See all data from seaborn
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\User\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df= sns.load_dataset("tips")

# %% [markdown]
# EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
len(df)
# Out:
# 244

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df['time'].unique
# Out:
# <bound method Series.unique of 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
#         ...
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# Name: time, Length: 244, dtype: category
# Categories (2, object): [Lunch, Dinner]>

# %%
df['time'].value_counts().plot()

# %% [markdown]
# # Correlation with Heatmap
# *A heat map (or heatmap) is a data visualization technique that shows magnitude of a phenomenon as color in two dimensions. The variation in color may be by hue or intensity, giving obvious visual cues to the reader about how the phenomenon is clustered or varies over space.

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# # Join Plot
# * Help in univariate or Bivarate analysis

# %%
sns.jointplot(df["tip"],df["size"],kind='scatter')  # you can also use hex etc

# %%
sns.jointplot(df["tip"],df["size"],kind='reg')  # you can also use hex etc. Fit a distribution and regression to the scatter plt

# %% [markdown]
# # Distribution Plots

# %%
sns.pairplot(df)

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(df, hue="sex")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
aa=list(df.columns)

# %%
cols=['sex', 'smoker', 'time','day']

# %%
for i in cols:
    sns.pairplot(df,hue=i)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
df["smoker"].value_counts().plot()

# %% [markdown]
# # Dist Plot

# %%
sns.distplot(df["tip"],kde=False,bins=10)

# %%
sns.distplot(df["tip"])

# %% [markdown]
# # Categorical Plots
# * COuntplot
# * Violinplot
# * BOxplot
# * barplot

# %%
sns.countplot(df["sex"])

# %%
sns.countplot(df["smoker"])

# %%
sns.countplot(df["day"])

# %%
sns.countplot(df["time"])

# %%
sns.countplot(y=df["time"])  # horizontal bar

# %% [markdown]
# # Barplots

# %%
sns.barplot(df["sex"],df["total_bill"])

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(df["smoker"],df["total_bill"])

# %%
sns.boxplot(df["day"],df["total_bill"],palette="rainbow")

# %%
sns.boxplot(df["day"],df["total_bill"],palette="rainbow",hue=df["sex"])

# %%
sns.violinplot(df["day"],df["total_bill"],palette="rainbow",hue=df["sex"])

# %%
sns.violinplot(df["sex"],df["total_bill"],palette="rainbow")
